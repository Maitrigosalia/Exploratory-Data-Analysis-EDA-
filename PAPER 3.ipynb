# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Q1
a=[10, 20, 20, 25, 30, 35, 40, 50]
plt.hist(a,bins=5,edgecolor="black")
# Out:
# (array([1., 3., 1., 2., 1.]),
#  array([10., 18., 26., 34., 42., 50.]),
#  <BarContainer object of 5 artists>)

# %%
#Q2
a=[1, 3, 5, 7, 9, 15, 20, 25]
plt.boxplot(a)
Q1=np.percentile(a,25)
Q3=np.percentile(a,75)
iqr=Q3-Q1
lb=Q1-1.5*iqr
ub=Q3+1.5*iqr

print(lb, " ",ub)
# Out:
# -13.125   33.875

# %%
#Q3
x = [2, 4, 6, 8, 10]
y = [3, 6, 9, 12, 15]
plt.scatter(x,y,color="red")

# %%
#Q4
l={'Letters': ['A', 'B', 'A', 'C', 'B', 'C', 'A']}
print(l['Letters'])
d={}
for i in l['Letters']:
    if i in d:
        d[i]=d[i]+1
    else:
        d[i]=1

print(d)
plt.bar(d.keys(),d.values())
# Out:
# ['A', 'B', 'A', 'C', 'B', 'C', 'A']
# {'A': 3, 'B': 2, 'C': 2}
# <BarContainer object of 3 artists>

# %%
#Q5
x={'Fruits': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Banana', 'Orange', 'Apple']}
print(x['Fruits'])
d={}
for i in x['Fruits']:
    if i in d:
        d[i]=d[i]+1
    else:
        d[i]=1
print(d)
plt.bar(d.keys(),d.values())
# Out:
# ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Banana', 'Orange', 'Apple']
# {'Apple': 3, 'Banana': 3, 'Orange': 2}
# <BarContainer object of 3 artists>

# %%
#Q6
d = [5, 7, 8, 12, 15, 18, 19, 20, 35, 37]
plt.boxplot(d)

Q1=np.percentile(d,25)
Q3=np.percentile(d,75)
IQR=Q3-Q1

lp=Q1-1.5*IQR
up=Q3+1.5*IQR

print(lb," ",ub)
# Out:
# -13.125   33.875

# %%
#Q7
x=['Dog', 'Cat', 'Bird']
y=[3, 5, 2]
plt.bar(x,y,color="green")
# Out:
# <BarContainer object of 3 artists>

# %%
#Q10 
age= [5, 7, 8, 12, 15, 18, 19, 20, 35, 37]

plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.hist(a,bins=5,edgecolor="black",color="blue")
# Out:
# (array([3., 2., 1., 1., 1.]),
#  array([ 1. ,  5.8, 10.6, 15.4, 20.2, 25. ]),
#  <BarContainer object of 5 artists>)

# %%
#Q11
np.random.seed(0)
a=np.random.randint(100000,500000,size=100)
a
plt.title("price dist")
plt.hist(a,bins=10,edgecolor="grey",color="pink")
# Out:
# (array([ 9., 10., 11.,  8.,  8., 12.,  9.,  9., 10., 14.]),
#  array([107877. , 146852.9, 185828.8, 224804.7, 263780.6, 302756.5,
#         341732.4, 380708.3, 419684.2, 458660.1, 497636. ]),
#  <BarContainer object of 10 artists>)

# %%
#Q12
d={'Age': [25, 30, 35, None, 28, 32, 45, None, 30, 28]}
df=pd.DataFrame(d)
df
df.dropna()
plt.hist(df['Age'],bins=10,color="red")
# Out:
# (array([1., 2., 2., 1., 0., 1., 0., 0., 0., 1.]),
#  array([25., 27., 29., 31., 33., 35., 37., 39., 41., 43., 45.]),
#  <BarContainer object of 10 artists>)

# %%
#Q13
a= ['Logistic Regression', 'SVM', 'Random Forest'] 
t = [2.1, 12.5, 8.4]
plt.barh(a,t,color="green")
# Out:
# <BarContainer object of 3 artists>

# %%
#Q14
Shape = ['Square1', 'Rect', 'Square2']
Length = [10, 15, 20]
Height = [12, 18, 25]
plt.bar(Shape,Length,color="red")
plt.bar(Shape,Height,color="green")
# Out:
# <BarContainer object of 3 artists>

# %%
#Q15
h= [1000, 1500, 2000, 2500, 3000] 
pr = [200000, 250000,300000, 350000,400000]
a = [200000, 250000, 300000, 350000, 400000] 
rpr =[210000, 245000,290000, 360000, 390000]

plt.subplot(2,2,1)
plt.scatter(h,pr,color="green")
plt.grid(True)
plt.show()

plt.subplot(2,2,2)
plt.scatter(a,rpr,color="red")
plt.grid(True)

# %%
#Q16
t= [10, 15, 20, 25, 30, 35, 1000, 2000]
cv1 = [0.82, 0.84, 0.83, 0.81, 0.95]
cv2= [0.88, 0.87, 0.89, 0.86, 0.88]
r= [0.01, 0.02, 0.015, -0.03, 0.02, -0.1, 0.03, 0.08]

d={"Transaction Amount":t,"CV Score 1":cv1,"CV Score 2":cv2,"Returns":r}

plt.boxplot(d.values())

q1=np.percentile(d.values,25)
q3=np.percentile(d.values,75)
iqr=q3-q1

lb=q1+1.5*iqr
ub=a3-1.5*iqr

print(lb," ",ub)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 11
#       7 d={"Transaction Amount":t,"CV Score 1":cv1,"CV Score 2":cv2,"Returns":r}
#       9 plt.boxplot(d.values())
# ---> 11 q1=np.percentile(d.values,25)
#      12 q3=np.percentile(d.values,75)
#      13 iqr=q3-q1
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
# ...
