# %%
#Q1
#drop duplicate key and values

import pandas as pd
import numpy as np

d=[{'John':24},{'Anna':13},{'Peter':53},{'John':24}]
df=pd.DataFrame(d)
df

df=df.drop(3,axis=0)
df
# Out:
#    John  Anna  Peter
# 0  24.0   NaN    NaN
# 1   NaN  13.0    NaN
# 2   NaN   NaN   53.0

# %%
#Q2
#drop missing values
d={'Name': ['John', 'Anna', 'Peter', None], 'Age': [24, 13, None, 33]}
df=pd.DataFrame(d)
df

#df=df.dropna()
#df

a=df.fillna(35,inplace=True)
a

# %%
#Q3
#Standardize date format in dataset

d={'Date': ['2023-01-01', '01/02/2023', '2023.03.03']}
df=pd.to_datetime(d)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 #Q3
#       2 #Standardize date format in dataset
#       4 d={'Date': ['2023-01-01', '01/02/2023', '2023.03.03']}
# ----> 5 df=pd.to_datetime(d)
#       6 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1070, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1070     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1071 elif isinstance(arg, Index):
#    1072     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...

# %%
#Q4
#Write a Machine Learning program to filter out irrelevant or erroneous data points from a dataset based on predefined criteria,

d={'Name': ['John', 'Anna', 'Peter', 'Linda'],'Age': [24, 13, 53, 33], 'Salary': [50000, 2000, 100000, 30000]}
df=pd.DataFrame(d)
x=df[(df['Age']>25)&(df['Age']<=60)]
x

y=df[(df['Salary']>10000)]
y
# Out:
#     Name  Age  Salary
# 0   John   24   50000
# 2  Peter   53  100000
# 3  Linda   33   30000

# %%
#Q5

t=("<html>Hello! This is <b>clean</b> text.</html>")
df=pd.DataFrame(t)
df

# %%
#Q6

d={'Department': ['HR', 'Legal', 'Marketing', 'Management']}
df=pd.DataFrame(d)


df=df.rename(columns={"Department":"Dept"},index={0:'r1',1:'r2',2:'r3',3:'r4'})
df
# Out:
#           Dept
# r1          HR
# r2       Legal
# r3   Marketing
# r4  Management

# %%
#Q7
d={'Income': [15000, 1800, 120000, 10000], 'Age': [25, 18, 42, 51]}
df=pd.DataFrame(d)

#a=[(df['Income'])&(df['Age'])].max()


b=df['Age'].max()
c=df['Income'].max()
print(b," ",c)
# Out:
# 51   120000

# %%
#Q8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=np.random.exponential(scale=2, size=1000)
#print(data)


plt.plot(data,label='skewed distributions',color='green')
plt.xlabel("square root")
plt.ylabel("scale")
plt.legend()
plt.show()

# %%
#Q9

# %%
#Q10
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c=b-a
print("substraction",c)
d=a**b
print("multiplication",d)
e=b**2
print("square",e)
# Out:
# substraction [3 3 3]
# multiplication [  1  32 729]
# square [16 25 36]

# %%
#Q11

d=np.array([1,101])
df=pd.DataFrame(d).mean()
print("mean",df)

a=pd.DataFrame(d).std()
print("std deviatation",a)
# Out:
# mean 0    51.0
# dtype: float64
# std deviatation 0    70.710678
# dtype: float64

# %%
#Q12- DOUBT
import pandas as pd
import numpy as np

df={'Name':['John','Anna','Peter','Linda'],'Location':['Newyork','Paris','Berlin','London'],'Age':[24,13,53,33]}
df=pd.DataFrame(df)
#condition 1
df


#condition 2
print(df[df['Age']>30])

#condition 3
print(df.head(1))

#condition 4
print(df.head(2))
# Out:
#     Name Location  Age
# 2  Peter   Berlin   53
# 3  Linda   London   33
#    Name Location  Age
# 0  John  Newyork   24
#    Name Location  Age
# 0  John  Newyork   24
# 1  Anna    Paris   13

# %%
#Q13

import pandas as pd
import numpy as np

df=pd.read_csv("C:\\Users\\INDIA\\Documents\\Maitri CTAG Python\\csv\\CAR DATA'.csv")
df

#condition 2
a=df.head()
a

b=df.tail()
b
# Out:
#           Make  Year  Engine HP  Engine Cylinders Transmission Type  \
# 11909    Acura  2012      300.0               6.0         AUTOMATIC
# 11910    Acura  2012      300.0               6.0         AUTOMATIC
# 11911    Acura  2012      300.0               6.0         AUTOMATIC
# 11912    Acura  2013      300.0               6.0         AUTOMATIC
# 11913  Lincoln  2006      221.0               6.0         AUTOMATIC
#
#        Number of Doors  Vehicle Style  highway MPG  city mpg  Popularity  \
# 11909              4.0  4dr Hatchback           23        16         204
# 11910              4.0  4dr Hatchback           23        16         204
# 11911              4.0  4dr Hatchback           23        16         204
# 11912              4.0  4dr Hatchback           23        16         204
# 11913              4.0          Sedan           26        17          61
#
#         MSRP Vehicle Size
# 11909  46120      Midsize
# 11910  56670      Midsize
# 11911  50620      Midsize
# ...

# %%
#Q14
import pandas as pd
import numpy as np

d={'Income':['15000','1800','120000','10000'],'Age':['25','18','42','51'],'Dep':['HR','Legal','Marketing','Management']}
df=pd.DataFrame(d)
df

a=df['Income'].max()
b=df['Age'].max()
print('Max Income & age=',a,b)

c=df['Income'].min()
d=df['Age'].min()
print('Min Income and age =',c,d)
# Out:
# Max Income & age= 1800 51
# Min Income and age = 10000 18

# %%
#Q15
import pandas as pd
import numpy as np

d={'Income':['15000','1800','120000','10000'],'Age':['25','18','42','51'],'Dep':['HR','Legal','Marketing','Management']}
df=pd.DataFrame(d)
df

a=df['Dep']
a
# Out:
# 0            HR
# 1         Legal
# 2     Marketing
# 3    Management
# Name: Dep, dtype: object

# %%
#Q16
import pandas as pd
import numpy as np


d={'Name':['Alex','Bob','Clearke'],' Age': [10,12,13]}
df=pd.DataFrame(d)
df
# Out:
#       Name   Age
# 0     Alex    10
# 1      Bob    12
# 2  Clearke    13

# %%
#Q16

import numpy as np
import pandas as pd

df=pd.read_csv("C:\\Users\\INDIA\\Documents\\Maitri CTAG Python\\csv\\employees.csv")
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     50 non-null     int64
#  1   FIRST_NAME      50 non-null     object
#  2   LAST_NAME       50 non-null     object
#  3   EMAIL           50 non-null     object
#  4   PHONE_NUMBER    50 non-null     object
#  5   HIRE_DATE       50 non-null     object
#  6   JOB_ID          50 non-null     object
#  7   SALARY          50 non-null     int64
#  8   COMMISSION_PCT  50 non-null     object
#  9   MANAGER_ID      50 non-null     object
#  10  DEPARTMENT_ID   50 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 4.4+ KB

# %%
print(df['FIRST_NAME'],df['SALARY'])
# Out:
# 0          Donald
# 1         Douglas
# 2        Jennifer
# 3         Michael
# 4             Pat
# 5           Susan
# 6         Hermann
# 7         Shelley
# 8         William
# 9          Steven
# 10          Neena
# 11            Lex
# 12      Alexander
# 13          Bruce
# 14          David
# 15          Valli
# 16          Diana
# 17          Nancy
# 18         Daniel
# 19           John
# 20         Ismael
# 21    Jose Manuel
# 22           Luis
# 23            Den
# 24      Alexander
# 25         Shelli
# 26          Sigal
# 27            Guy
# 28          Karen
# 29        Matthew
# 30           Adam
# 31          Payam
# 32         Shanta
# 33          Kevin
# 34          Julia
# 35          Irene
# 36          James
# 37         Steven
# 38          Laura
# 39          Mozhe
# 40          James
# 41             TJ
# 42          Jason
# 43        Michael
# 44             Ki
# 45          Hazel
# 46         Renske
# 47        Stephen
# 48           John
# 49         Joshua
# ...

# %%
a=df.head(1)
a
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50

# %%
a=df.head()
a
print(a['EMPLOYEE_ID']," ",a['FIRST_NAME'])

# %%
#df=df[df['FIRST_NAME'],df['LAST_NAME']]
x=df[['FIRST_NAME','LAST_NAME','SALARY']]
print(x)
# Out:
#      FIRST_NAME    LAST_NAME  SALARY
# 0        Donald     OConnell    2600
# 1       Douglas        Grant    2600
# 2      Jennifer       Whalen    4400
# 3       Michael    Hartstein   13000
# 4           Pat          Fay    6000
# 5         Susan       Mavris    6500
# 6       Hermann         Baer   10000
# 7       Shelley      Higgins   12008
# 8       William        Gietz    8300
# 9        Steven         King   24000
# 10        Neena      Kochhar   17000
# 11          Lex      De Haan   17000
# 12    Alexander       Hunold    9000
# 13        Bruce        Ernst    6000
# 14        David       Austin    4800
# 15        Valli    Pataballa    4800
# 16        Diana      Lorentz    4200
# 17        Nancy    Greenberg   12008
# 18       Daniel       Faviet    9000
# 19         John         Chen    8200
# 20       Ismael      Sciarra    7700
# 21  Jose Manuel        Urman    7800
# 22         Luis         Popp    6900
# 23          Den     Raphaely   11000
# ...

# %%
y=df[df['DEPARTMENT_ID']>70][['FIRST_NAME','LAST_NAME','SALARY','DEPARTMENT_ID']]
y
# Out:
#      FIRST_NAME  LAST_NAME  SALARY  DEPARTMENT_ID
# 7       Shelley    Higgins   12008            110
# 8       William      Gietz    8300            110
# 9        Steven       King   24000             90
# 10        Neena    Kochhar   17000             90
# 11          Lex    De Haan   17000             90
# 17        Nancy  Greenberg   12008            100
# 18       Daniel     Faviet    9000            100
# 19         John       Chen    8200            100
# 20       Ismael    Sciarra    7700            100
# 21  Jose Manuel      Urman    7800            100
# 22         Luis       Popp    6900            100

# %%
print(df['FIRST_NAME'],df['LAST_NAME'])
# Out:
# 0          Donald
# 1         Douglas
# 2        Jennifer
# 3         Michael
# 4             Pat
# 5           Susan
# 6         Hermann
# 7         Shelley
# 8         William
# 9          Steven
# 10          Neena
# 11            Lex
# 12      Alexander
# 13          Bruce
# 14          David
# 15          Valli
# 16          Diana
# 17          Nancy
# 18         Daniel
# 19           John
# 20         Ismael
# 21    Jose Manuel
# 22           Luis
# 23            Den
# 24      Alexander
# 25         Shelli
# 26          Sigal
# 27            Guy
# 28          Karen
# 29        Matthew
# 30           Adam
# 31          Payam
# 32         Shanta
# 33          Kevin
# 34          Julia
# 35          Irene
# 36          James
# 37         Steven
# 38          Laura
# 39          Mozhe
# 40          James
# 41             TJ
# 42          Jason
# 43        Michael
# 44             Ki
# 45          Hazel
# 46         Renske
# 47        Stephen
# 48           John
# 49         Joshua
# ...

# %%
a=df.head(1)
a
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50

# %%
y=df.head()
z=y[['FIRST_NAME','LAST_NAME']]
z
# Out:
#   FIRST_NAME  LAST_NAME
# 0     Donald   OConnell
# 1    Douglas      Grant
# 2   Jennifer     Whalen
# 3    Michael  Hartstein
# 4        Pat        Fay

# %%
a=df.head(10)
x=a[['FIRST_NAME','LAST_NAME','SALARY']]
x
# Out:
#   FIRST_NAME  LAST_NAME  SALARY
# 0     Donald   OConnell    2600
# 1    Douglas      Grant    2600
# 2   Jennifer     Whalen    4400
# 3    Michael  Hartstein   13000
# 4        Pat        Fay    6000
# 5      Susan     Mavris    6500
# 6    Hermann       Baer   10000
# 7    Shelley    Higgins   12008
# 8    William      Gietz    8300
# 9     Steven       King   24000

# %%
y=df[df['DEPARTMENT_ID']>70][['FIRST_NAME','LAST_NAME','SALARY','DEPARTMENT_ID']]
y
# Out:
#      FIRST_NAME  LAST_NAME  SALARY  DEPARTMENT_ID
# 7       Shelley    Higgins   12008            110
# 8       William      Gietz    8300            110
# 9        Steven       King   24000             90
# 10        Neena    Kochhar   17000             90
# 11          Lex    De Haan   17000             90
# 17        Nancy  Greenberg   12008            100
# 18       Daniel     Faviet    9000            100
# 19         John       Chen    8200            100
# 20       Ismael    Sciarra    7700            100
# 21  Jose Manuel      Urman    7800            100
# 22         Luis       Popp    6900            100

# %%
a=df.head(10)
b=df.drop(['COMMISSION_PCT','EMAIL'],axis=1)
b
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  515.123.5555  17-FEB-04
# 4           202          Pat          Fay  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  515.123.8080  07-JUN-02
# 8           206      William        Gietz  515.123.8181  07-JUN-02
# 9           100       Steven         King  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  515.123.4568  21-SEP-05
# 11          102          Lex      De Haan  515.123.4569  13-JAN-01
# 12          103    Alexander       Hunold  590.423.4567  03-JAN-06
# ...

# %%
x=df[df.duplicated()]
x.count()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %%
#count duplicates
a=df[df['DEPARTMENT_ID']].duplicated()
a.count()

#drop duplicates
x=a['DEPARTMENT_ID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 a=df[df['DEPARTMENT_ID']].duplicated()
#       2 a.count()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
#y=df.drop_duplicates()
df.shape
# Out:
# (50, 11)

# %%
a=df[df['DEPARTMENT_ID'].duplicated()]
#a.count()

Z=df.drop_duplicates('DEPARTMENT_ID')
Z
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 2           200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 5           203      Susan     Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204    Hermann       Baer     HBAER  515.123.8888  07-JUN-02
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 12          103  Alexander     Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 23          114        Den   Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0   SH_CLERK    2600             -         124             50
# ...

# %%
df.isnull().sum()

df=df.dropna(axis=0)
df.count()

df.isnull().sum()
# Out:
# 0

# %%
df=pd.read_csv("C:\\Users\\INDIA\\Documents\\Maitri CTAG Python\\csv\\employees.csv")
df
total_rows=df.shape[0]
sum_of_null_val=df['PHONE_NUMBER'].isnull().sum()
per=sum_of_null_val/total_rows
per
# Out:
# 0.08
