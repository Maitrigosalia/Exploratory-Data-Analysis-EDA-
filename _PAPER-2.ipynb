# %%
#Q1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

d=[55,45,12,44,85,15,49,38,75,41,66]
df=pd.DataFrame(d,columns=['Age'])
plt.xlabel("age")
plt.ylabel("count")
plt.hist(df['Age'],bins=5,edgecolor="black",color="blue")
plt.show()

# %%
#Q2
import random
import numpy as np

a=np.random.randint(100000,500000,size=100)
df=pd.DataFrame(a,columns=["price"])
plt.xlabel("price")
plt.ylabel("count")
plt.title("property price")
plt.hist(df['price'],color="pink",edgecolor="gray",label="property price")
plt.legend()

# %%
#Q3
d={'Age': [25, 30, 35, None, 28, 32, 45, None, 30, 28]} 
df=pd.DataFrame(d)
df

df=df.dropna()
df
plt.xlabel("age")
plt.ylabel("count")
plt.title("age graph")
plt.hist(df['Age'],bins=10,color="green",edgecolor="red")
# Out:
# (array([1., 2., 2., 1., 0., 1., 0., 0., 0., 1.]),
#  array([25., 27., 29., 31., 33., 35., 37., 39., 41., 43., 45.]),
#  <BarContainer object of 10 artists>)

# %%
#Q4
d={'model' :['Logistic Regression', 'SVM', 'Random Forest'], 't' :[2.1, 12.5, 8.4]}
df=pd.DataFrame(d)
df

x=df['model']
y=df['t']
plt.xlabel("training")
plt.ylabel("model")
plt.barh(x,y,color="green")
# Out:
# <BarContainer object of 3 artists>

# %%
#Q5
s= ['Square1', 'Rect', 'Square2']
l= [10, 15, 20]
h= [12, 18, 25]
plt.bar(s,l,color="green")
plt.bar(s,h,color="red")
plt.show()

# %%
#Q6
s=[1000, 1500, 2000, 2500, 3000] 
p=[200000, 250000, 300000, 350000, 400000]
a=[200000, 250000, 300000, 350000, 400000] 
p= [210000, 245000, 290000, 360000, 390000]

plt.figure(figsize=(5,2))

plt.subplot(1,2,1)
plt.xlabel("size")
plt.ylabel("price")
plt.scatter(s,p,label="prices",color="green")
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(5,2))

plt.subplot(1,2,2)
plt.xlabel("actual")
plt.ylabel("predeicted")
plt.scatter(a,p,label="prices",color="red")
plt.grid(True)
plt.legend()
plt.show()

# %%
#Q7

t= [10, 15, 20, 25, 30, 35, 1000, 2000] 
cv1= [0.82, 0.84, 0.83, 0.81, 0.95] 
cv2 = [0.88, 0.87, 0.89, 0.86, 0.88] 
r= [0.01, 0.02, 0.015, -0.03, 0.02, -0.1, 0.03, 0.08]

d={"Transaction Amount":t,"CV Score 1":cv1,"CV Score 2":cv2,"Returns":r}

plt.boxplot(d.values())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2326885d610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2326885dac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23268504260>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2326885e030>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2326885e300>,
# ...
#  'means': []}

# %%
AGAIN ALL QUESTIONS
# Out:
#   Cell In[11], line 1
#     AGAIN ALL QUESTIONS
#           ^
# SyntaxError: invalid syntax

# %%
#Q1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

d=[45,88,52,74,66,98,10,33,87,54,28]
df=pd.DataFrame(d,columns=['Age'])
df

plt.xlabel("age")
plt.ylabel("count")
plt.hist(df['Age'],bins=5,edgecolor="black",color="blue")
plt.show()

# %%
#Q2

import random
np.random.seed(0)
a=np.random.randint(100000,500000,size=100)
df=pd.DataFrame(a,columns=['Price'])
df

plt.xlabel("price")
plt.ylabel("count")
plt.hist(df['Price'],bins=10,edgecolor="gray",color="pink",label="house price")
plt.legend()
plt.show()

# %%
#Q3
d={'Age': [25, 30, 35, None, 28, 32, 45, None, 30, 28]}
df=pd.DataFrame(d)
df

df=df.dropna()
df

plt.xlabel("age")
plt.hist(df['Age'],bins=[10,20,30,40,50],color="red",edgecolor="yellow",label="age")
plt.legend()
plt.show()

# %%
#Q4
d={'m':['Logistic Regression', 'SVM', 'Random Forest'], 't': [2.1, 12.5, 8.4]}
df=pd.DataFrame(d)
df
'''
x=df['m']
y=df['t']
plt.xlabel("model")
plt.ylabel("training")
plt.barh(x,y,color="green")
'''

x=df['m']
y=df['t']
plt.xlabel("training")
plt.ylabel("model")
plt.barh(x,y,color="green")

# %%
#Q4
a= ['Logistic Regression', 'SVM', 'Random Forest'] 
b= [2.1, 12.5, 8.4]

plt.barh(a,b,color="green")
plt.show()

# %%
#Q5
s=['Square1', 'Rect', 'Square2']
l=[10, 15, 20]
h=[12, 18, 25]

plt.bar(s,l,color="green")
plt.bar(s,h,color="red")
plt.show()

# %%
#Q6
size = [1000, 1500, 2000, 2500, 3000] 
price = [200000, 250000, 300000, 350000, 400000]
actual = [200000, 250000, 300000, 350000, 400000] 
predicted= [210000, 245000, 290000, 360000, 390000]

plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plt.xlabel("size")
plt.title("size/price")
plt.scatter(size,price,color="green")
plt.grid(True)
plt.show()

plt.figure(figsize=(6,3))
plt.subplot(1,2,2)
plt.xlabel("price")
plt.title("actual/predicted")
plt.scatter(actual,predicted,color="red")
plt.grid(True)
plt.show()

# %%
#Q7
t= [10, 15, 20, 25, 30, 35, 1000, 2000] 
cv1 = [0.82, 0.84, 0.83, 0.81, 0.95] 
cv2 = [0.88, 0.87, 0.89, 0.86, 0.88] 
r= [0.01, 0.02, 0.015, -0.03, 0.02, -0.1, 0.03, 0.08]

d={"Transaction Amount":t,"CV Score 1":cv1,"CV Score 2":cv2,"Returns":r}
plt.boxplot(d.values())
